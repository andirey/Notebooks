# %% [markdown]
# # Chapter 6. Accessing Data

# %%
import numpy as np
import pandas as pd

# pd.set_option('display.notebook_repr_html', False)
pd.set_option('display.max_columns', 10)
pd.set_option('display.max_rows', 10)

# %%
# !head -n 5 msft.csv
# Out:
# Date,Open,High,Low,Close,Volume,Adj Close
# 2016-02-23,52.34,52.369999,50.98,51.18,28390800,51.18
# 2016-02-22,52.279999,53.00,52.279999,52.650002,24854400,52.650002
# 2016-02-19,51.970001,52.279999,51.529999,51.82,33275400,51.82
# 2016-02-18,52.330002,52.950001,52.099998,52.189999,26244700,52.189999

# %%
msft = pd.read_csv('msft.csv')
msft.head()
# Out:
#          Date       Open       High        Low      Close    Volume  Adj Close
# 0  2016-02-23  52.340000  52.369999  50.980000  51.180000  28390800  51.180000
# 1  2016-02-22  52.279999  53.000000  52.279999  52.650002  24854400  52.650002
# 2  2016-02-19  51.970001  52.279999  51.529999  51.820000  33275400  51.820000
# 3  2016-02-18  52.330002  52.950001  52.099998  52.189999  26244700  52.189999
# 4  2016-02-17  51.490002  52.770000  51.450001  52.419998  39670300  52.419998

# %%
# specify a column as index
msft = pd.read_csv('msft.csv', index_col=0)
msft.head()
# Out:
#                  Open       High        Low      Close    Volume  Adj Close
# Date
# 2016-02-23  52.340000  52.369999  50.980000  51.180000  28390800  51.180000
# 2016-02-22  52.279999  53.000000  52.279999  52.650002  24854400  52.650002
# 2016-02-19  51.970001  52.279999  51.529999  51.820000  33275400  51.820000
# 2016-02-18  52.330002  52.950001  52.099998  52.189999  26244700  52.189999
# 2016-02-17  51.490002  52.770000  51.450001  52.419998  39670300  52.419998

# %%
msft.dtypes
# Out:
# Open         float64
# High         float64
# Low          float64
# Close        float64
# Volume         int64
# Adj Close    float64
# dtype: object

# %%
# specify column type
msft = pd.read_csv("msft.csv", 
                    dtype = { 'Volume' : np.float64})
msft.dtypes
# Out:
# Date          object
# Open         float64
# High         float64
# Low          float64
# Close        float64
# Volume       float64
# Adj Close    float64
# dtype: object

# %%
# specify column names
df = pd.read_csv('msft.csv',
                   names = ['open', 'high', 'low',
                           'close', 'volume', 'adjclose'])
df.head()
# Out:
#                  open       high        low      close    volume   adjclose
# Date             Open       High        Low      Close    Volume  Adj Close
# 2016-02-23      52.34  52.369999      50.98      51.18  28390800      51.18
# 2016-02-22  52.279999      53.00  52.279999  52.650002  24854400  52.650002
# 2016-02-19  51.970001  52.279999  51.529999      51.82  33275400      51.82
# 2016-02-18  52.330002  52.950001  52.099998  52.189999  26244700  52.189999

# %%
df2 = pd.read_csv("msft.csv",
                  usecols=['Date', 'Close'],
                  index_col=['Date'])
df2.head()
# Out:
#                 Close
# Date
# 2016-02-23  51.180000
# 2016-02-22  52.650002
# 2016-02-19  51.820000
# 2016-02-18  52.189999
# 2016-02-17  52.419998

# %% [markdown]
# # Saving

# %%
df2.to_csv("msft_temp.csv", index_label='date')

# %%
# !head msft_temp.csv
# Out:
# date,Close
# 2016-02-23,51.18
# 2016-02-22,52.650002
# 2016-02-19,51.82
# 2016-02-18,52.189999
# 2016-02-17,52.419998
# 2016-02-16,51.09
# 2016-02-12,50.5
# 2016-02-11,49.689999
# 2016-02-10,49.709998999999996

# %%
df = pd.read_table("msft.csv", sep=",")
df.head()
# Out:
#          Date       Open       High        Low      Close    Volume  Adj Close
# 0  2016-02-23  52.340000  52.369999  50.980000  51.180000  28390800  51.180000
# 1  2016-02-22  52.279999  53.000000  52.279999  52.650002  24854400  52.650002
# 2  2016-02-19  51.970001  52.279999  51.529999  51.820000  33275400  51.820000
# 3  2016-02-18  52.330002  52.950001  52.099998  52.189999  26244700  52.189999
# 4  2016-02-17  51.490002  52.770000  51.450001  52.419998  39670300  52.419998

# %%
df.to_csv("msft_temp2.txt", sep="|")
! head -5 msft_temp2.txt
# Out:
# |Date|Open|High|Low|Close|Volume|Adj Close
# 0|2016-02-23|52.34|52.369999|50.98|51.18|28390800|51.18
# 1|2016-02-22|52.279999|53.0|52.279999|52.650002|24854400|52.650002
# 2|2016-02-19|51.970001|52.279999|51.529999|51.82|33275400|51.82
# 3|2016-02-18|52.330002|52.950001|52.099998|52.189999|26244700|52.189999

# %%
df = pd.read_csv("msft.csv", skiprows=[0, 2, 3])
df
# Out:
#       2016-02-23      52.34  52.369999      50.98      51.18    28390800  \
# 0     2016-02-18  52.330002  52.950001  52.099998  52.189999    26244700
# 1     2016-02-17  51.490002  52.770000  51.450001  52.419998    39670300
# 2     2016-02-16  50.900002  51.090000  50.130001  51.090000    35937100
# 3     2016-02-12  50.250000  50.680000  49.750000  50.500000    34243300
# 4     2016-02-11  48.680000  50.110001  48.509998  49.689999    48878600
# ...          ...        ...        ...        ...        ...         ...
# 7542  1986-03-19  28.751040  28.998720  27.999361  28.249920    47894400
# 7543  1986-03-18  29.499840  29.750399  28.500479  28.751040    67766400
# 7544  1986-03-17  28.998720  29.750399  28.998720  29.499840   133171200
# 7545  1986-03-14  27.999361  29.499840  27.999361  28.998720   308160000
# 7546  1986-03-13  25.499521  29.249279  25.499521  27.999361  1031788800
#
#         51.18.1
# 0     52.189999
# 1     52.419998
# 2     51.090000
# 3     50.140000
# 4     49.335773
# ...         ...
# 7542   0.067943
# 7543   0.069148
# 7544   0.070949
# 7545   0.069744
# 7546   0.067340
#
# [7547 rows x 7 columns]

# %%
df = pd.read_csv("msft.csv", 
                skip_footer = 2,
                engine = 'python')
df
# Out:
#             Date       Open       High        Low      Close     Volume  \
# 0     2016-02-23  52.340000  52.369999  50.980000  51.180000   28390800
# 1     2016-02-22  52.279999  53.000000  52.279999  52.650002   24854400
# 2     2016-02-19  51.970001  52.279999  51.529999  51.820000   33275400
# 3     2016-02-18  52.330002  52.950001  52.099998  52.189999   26244700
# 4     2016-02-17  51.490002  52.770000  51.450001  52.419998   39670300
# ...          ...        ...        ...        ...        ...        ...
# 7543  1986-03-21  27.501120  27.999361  26.251200  26.749441   59990400
# 7544  1986-03-20  28.249920  28.249920  27.250559  27.501120   58435200
# 7545  1986-03-19  28.751040  28.998720  27.999361  28.249920   47894400
# 7546  1986-03-18  29.499840  29.750399  28.500479  28.751040   67766400
# 7547  1986-03-17  28.998720  29.750399  28.998720  29.499840  133171200
#
#       Adj Close
# 0     51.180000
# 1     52.650002
# 2     51.820000
# 3     52.189999
# 4     52.419998
# ...         ...
# 7543   0.064334
# 7544   0.066142
# 7545   0.067943
# 7546   0.069148
# 7547   0.070949
#
# [7548 rows x 7 columns]

# %%
pd.read_csv("msft.csv", nrows=3)
# Out:
#          Date       Open       High        Low      Close    Volume  Adj Close
# 0  2016-02-23  52.340000  52.369999  50.980000  51.180000  28390800  51.180000
# 1  2016-02-22  52.279999  53.000000  52.279999  52.650002  24854400  52.650002
# 2  2016-02-19  51.970001  52.279999  51.529999  51.820000  33275400  51.820000

# %%
pd.read_csv("msft.csv", skiprows=100, nrows=5, header=0,
           names=['open', 'high', 'low', 'close', 'val', 'adjClose'])
# Out:
#                  open       high        low      close       val   adjClose
# 2015-09-29  43.369999  43.570000  43.049999  43.439999  32763600  42.841561
# 2015-09-28  43.830002  44.090000  43.209999  43.290001  27613800  42.693630
# 2015-09-25  44.480000  44.730000  43.759998  43.939999  29384600  43.334673
# 2015-09-24  43.450001  44.130001  43.270000  43.910000  27905600  43.305088
# 2015-09-23  43.930000  44.169998  43.509998  43.869999  17145200  43.265638

# %%
df = pd.read_excel("msft.xls")
# df = pd.read_excel("msft.xls", sheetname='aapl) #sheetname
df.head()
# Out:
#          Date       Open       High        Low      Close    Volume  Adj Close
# 0  2016-02-23  52.340000  52.369999  50.980000  51.180000  28390800  51.180000
# 1  2016-02-22  52.279999  53.000000  52.279999  52.650002  24854400  52.650002
# 2  2016-02-19  51.970001  52.279999  51.529999  51.820000  33275400  51.820000
# 3  2016-02-18  52.330002  52.950001  52.099998  52.189999  26244700  52.189999
# 4  2016-02-17  51.490002  52.770000  51.450001  52.419998  39670300  52.419998

# %%
df.to_excel("msft.xls")

# %%
df.to_excel("msft.xls", sheet_name="msft")

# %% [markdown]
# *Multiple sheets*

# %%
from pandas import ExcelWriter

with ExcelWriter("multisheets.xls") as writer:
    df.to_excel(writer, sheet_name="sheet1")
    df.to_excel(writer, sheet_name="sheet2")

# %%
df.to_excel("msft_temp.xlsx")

# %% [markdown]
# # Reading and Writing JSON files

# %%
df.head().to_json("msft.json")
# !cat msft.json
# Out:
# {"Date":{"0":"2016-02-23","1":"2016-02-22","2":"2016-02-19","3":"2016-02-18","4":"2016-02-17"},"Open":{"0":52.34,"1":52.279999,"2":51.970001,"3":52.330002,"4":51.490002},"High":{"0":52.369999,"1":53.0,"2":52.279999,"3":52.950001,"4":52.77},"Low":{"0":50.98,"1":52.279999,"2":51.529999,"3":52.099998,"4":51.450001},"Close":{"0":51.18,"1":52.650002,"2":51.82,"3":52.189999,"4":52.419998},"Volume":{"0":28390800,"1":24854400,"2":33275400,"3":26244700,"4":39670300},"Adj Close":{"0":51.18,"1":52.650002,"2":51.82,"3":52.189999,"4":52.419998}}

# %%
df_from_json = pd.read_json("msft.json")
df_from_json.head(5)
# Out:
#    Adj Close      Close       Date       High        Low       Open    Volume
# 0  51.180000  51.180000 2016-02-23  52.369999  50.980000  52.340000  28390800
# 1  52.650002  52.650002 2016-02-22  53.000000  52.279999  52.279999  24854400
# 2  51.820000  51.820000 2016-02-19  52.279999  51.529999  51.970001  33275400
# 3  52.189999  52.189999 2016-02-18  52.950001  52.099998  52.330002  26244700
# 4  52.419998  52.419998 2016-02-17  52.770000  51.450001  51.490002  39670300

# %% [markdown]
# # HTML

# %%
url = "https://www.fdic.gov/bank/individual/failed/banklist.html"
banks = pd.read_html(url)
banks[0][0:5].ix[:,0:4]
# Out:
#                 Bank Name            City  ST   CERT
# 0  Hometown National Bank        Longview  WA  35156
# 1     The Bank of Georgia  Peachtree City  GA  35259
# 2            Premier Bank          Denver  CO  34112
# 3          Edgebrook Bank         Chicago  IL  57772
# 4    Doral BankEn Espanol        San Juan  PR  32102

# %%
banks[0]
# Out:
#                              Bank Name            City  ST   CERT  \
# 0               Hometown National Bank        Longview  WA  35156
# 1                  The Bank of Georgia  Peachtree City  GA  35259
# 2                         Premier Bank          Denver  CO  34112
# 3                       Edgebrook Bank         Chicago  IL  57772
# 4                 Doral BankEn Espanol        San Juan  PR  32102
# ..                                 ...             ...  ..    ...
# 537                 Superior Bank, FSB        Hinsdale  IL  32646
# 538                Malta National Bank           Malta  OH   6629
# 539    First Alliance Bank & Trust Co.      Manchester  NH  34264
# 540  National State Bank of Metropolis      Metropolis  IL   3815
# 541                   Bank of Honolulu        Honolulu  HI  21029
#
#                    Acquiring Institution       Closing Date  \
# 0                         Twin City Bank    October 2, 2015
# 1                          Fidelity Bank    October 2, 2015
# 2              United Fidelity Bank, fsb      July 10, 2015
# 3               Republic Bank of Chicago        May 8, 2015
# 4           Banco Popular de Puerto Rico  February 27, 2015
# ..                                   ...                ...
# 537                Superior Federal, FSB      July 27, 2001
# 538                    North Valley Bank        May 3, 2001
# 539  Southern New Hampshire Bank & Trust   February 2, 2001
# 540              Banterra Bank of Marion  December 14, 2000
# 541                   Bank of the Orient   October 13, 2000
#
#           Updated Date Loss Share Type Agreement Terminated Termination Date
# 0    February 12, 2016             NaN                  NaN              NaN
# 1    February 12, 2016             NaN                  NaN              NaN
# 2    December 17, 2015            none                  NaN              NaN
# 3        July 23, 2015            none                  NaN              NaN
# 4         May 13, 2015            none                  NaN              NaN
# ..                 ...             ...                  ...              ...
# 537    August 19, 2014            none                  NaN              NaN
# 538  November 18, 2002            none                  NaN              NaN
# 539  February 18, 2003            none                  NaN              NaN
# 540     March 17, 2005            none                  NaN              NaN
# 541     March 17, 2005            none                  NaN              NaN
#
# [542 rows x 10 columns]

# %%
banks[0].head(2).to_html("failed_banks.html")
! head -30 failed_banks.html
# Out:
# <table border="1" class="dataframe">
#   <thead>
#     <tr style="text-align: right;">
#       <th></th>
#       <th>Bank Name</th>
#       <th>City</th>
#       <th>ST</th>
#       <th>CERT</th>
#       <th>Acquiring Institution</th>
#       <th>Closing Date</th>
#       <th>Updated Date</th>
#       <th>Loss Share Type</th>
#       <th>Agreement Terminated</th>
#       <th>Termination Date</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th>0</th>
#       <td>Hometown National Bank</td>
#       <td>Longview</td>
#       <td>WA</td>
#       <td>35156</td>
#       <td>Twin City Bank</td>
#       <td>October 2, 2015</td>
#       <td>February 12, 2016</td>
#       <td>NaN</td>
#       <td>NaN</td>
#       <td>NaN</td>
#     </tr>

# %% [markdown]
# # HDF5

# %%
np.random.seed(123456)
df = pd.DataFrame(np.random.randn(8, 3),
                 index=pd.date_range('1/1/2000', periods=8),
                 columns=['A', 'B', 'C'])

store = pd.HDFStore('store.h5')
store['df'] = df
store
# Out:
# <class 'pandas.io.pytables.HDFStore'>
# File path: store.h5
# /df            frame        (shape->[8,3])

# %%
store = pd.HDFStore('store.h5')
df = store['df']
df
# Out:
#                    A         B         C
# 2000-01-01  0.469112 -0.282863 -1.509059
# 2000-01-02 -1.135632  1.212112 -0.173215
# 2000-01-03  0.119209 -1.044236 -0.861849
# 2000-01-04 -2.104569 -0.494929  1.071804
# 2000-01-05  0.721555 -0.706771 -1.039575
# 2000-01-06  0.271860 -0.424972  0.567020
# 2000-01-07  0.276232 -1.087401 -0.673690
# 2000-01-08  0.113648 -1.478427  0.524988

# %%
df.ix[0].A = 1

store['df'] = df

pd.HDFStore('store.h5')['df'].head(2)
# Out:
#                    A         B         C
# 2000-01-01  1.000000 -0.282863 -1.509059
# 2000-01-02 -1.135632  1.212112 -0.173215

# %% [markdown]
# # Accessing data on the web

# %%
df = pd.read_csv("http://ichart.yahoo.com/table.csv?s=MSFT&" +
           "a=5&b=1&c=2014&" +
           "d=5&e=30&f=2014&" +
           "g=d&ignore=.csv")
# df = pd.read_csv("http://ichart.yahoo.com/table.csv?s=MSFT&" +
#                 "a=5&b=1&c=2014&" +
#                 "d=5&e=30&f=2014&" +
#                 "g=d&ignore=.csv")
df[:5]
# Out:
#          Date       Open       High        Low      Close    Volume  Adj Close
# 0  2014-06-30  42.169998  42.209999  41.700001  41.700001  30805500  39.804237
# 1  2014-06-27  41.610001  42.290001  41.509998  42.250000  74640000  40.329232
# 2  2014-06-26  41.930000  41.939999  41.430000  41.720001  23604400  39.823328
# 3  2014-06-25  41.700001  42.049999  41.459999  42.029999  20049100  40.119233
# 4  2014-06-24  41.830002  41.939999  41.560001  41.750000  26509100  39.851963

# %%
df.describe()
# Out:
#               A         B         C
# count  8.000000  8.000000  8.000000
# mean  -0.092212 -0.538436 -0.261697
# std    1.024613  0.811842  0.908894
# min   -2.104569 -1.478427 -1.509059
# 25%   -0.198672 -1.055027 -0.906280
# 50%    0.195534 -0.600850 -0.423452
# 75%    0.387563 -0.389445  0.535496
# max    1.000000  1.212112  1.071804

# %% [markdown]
# # sqlite

# %%
import sqlite3

msft = pd.read_csv('msft.csv')
msft["Symbol"] = "MSFT"
aapl = pd.read_csv('aapl.csv')
aapl["Symbol"] = "AAPL"

connection = sqlite3.connect("stocks.sqlite")
msft.to_sql("STOCK_DATA", connection, if_exists="replace")
aapl.to_sql("STOCK_DATA", connection, if_exists="append")

connection.commit()
connection.close()
# Out:
# /Users/hs3m/anaconda3/lib/python3.5/site-packages/ipykernel/__main__.py:9: UserWarning: The spaces in these column names will not be changed. In pandas versions < 0.14, spaces were converted to underscores.
# /Users/hs3m/anaconda3/lib/python3.5/site-packages/ipykernel/__main__.py:10: UserWarning: The spaces in these column names will not be changed. In pandas versions < 0.14, spaces were converted to underscores.

# %% [markdown]
# *Reading*

# %%
connection = sqlite3.connect("stocks.sqlite")

stocks = pd.io.sql.read_sql("SELECT * FROM STOCK_DATA;",
                             connection, index_col="index")

connection.close()

stocks.head()
# Out:
#              Date       Open       High        Low      Close    Volume  \
# index
# 0      2016-02-23  52.340000  52.369999  50.980000  51.180000  28390800
# 1      2016-02-22  52.279999  53.000000  52.279999  52.650002  24854400
# 2      2016-02-19  51.970001  52.279999  51.529999  51.820000  33275400
# 3      2016-02-18  52.330002  52.950001  52.099998  52.189999  26244700
# 4      2016-02-17  51.490002  52.770000  51.450001  52.419998  39670300
#
#        Adj Close Symbol
# index
# 0      51.180000   MSFT
# 1      52.650002   MSFT
# 2      51.820000   MSFT
# 3      52.189999   MSFT
# 4      52.419998   MSFT

# %%
connection = sqlite3.connect("stocks.sqlite")

query = "SELECT * FROM STOCK_DATA WHERE Volume>29200100 AND Symbol='MSFT';"

items = pd.io.sql.read_sql(query, connection, index_col="index")
connection.close()

items
# Out:
#              Date       Open       High        Low      Close      Volume  \
# index
# 2      2016-02-19  51.970001  52.279999  51.529999  51.820000    33275400
# 4      2016-02-17  51.490002  52.770000  51.450001  52.419998    39670300
# 5      2016-02-16  50.900002  51.090000  50.130001  51.090000    35937100
# 6      2016-02-12  50.250000  50.680000  49.750000  50.500000    34243300
# 7      2016-02-11  48.680000  50.110001  48.509998  49.689999    48878600
# ...           ...        ...        ...        ...        ...         ...
# 7545   1986-03-19  28.751040  28.998720  27.999361  28.249920    47894400
# 7546   1986-03-18  29.499840  29.750399  28.500479  28.751040    67766400
# 7547   1986-03-17  28.998720  29.750399  28.998720  29.499840   133171200
# 7548   1986-03-14  27.999361  29.499840  27.999361  28.998720   308160000
# 7549   1986-03-13  25.499521  29.249279  25.499521  27.999361  1031788800
#
#        Adj Close Symbol
# index
# 2      51.820000   MSFT
# 4      52.419998   MSFT
# 5      51.090000   MSFT
# 6      50.140000   MSFT
# 7      49.335773   MSFT
# ...          ...    ...
# 7545    0.067943   MSFT
# 7546    0.069148   MSFT
# 7547    0.070949   MSFT
# 7548    0.069744   MSFT
# 7549    0.067340   MSFT
#
# [6917 rows x 8 columns]

# %% [markdown]
# # Remote data services

# %%
import pandas.io.data as web
import datetime

start = datetime.datetime(2012, 1, 1)
end = datetime.datetime(2014, 1, 27)

yahoo = web.DataReader('MSFT', 'yahoo', start, end)
yahoo.head()
# Out:
# /Users/hs3m/anaconda3/lib/python3.5/site-packages/pandas/io/data.py:33: FutureWarning:
# The pandas.io.data module is moved to a separate package (pandas-datareader) and will be removed from pandas in a future version.
# After installing the pandas-datareader package (https://github.com/pydata/pandas-datareader), you can change the import ``from pandas.io import data, wb`` to ``from pandas_datareader import data, wb``.
#   FutureWarning)
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# <ipython-input-75-c9cdfcc967ca> in <module>()
#       5 end = datetime.datetime(2014, 1, 27)
#       6
# ----> 7 yahoo = web.DAtaReader('MSFT', 'yahoo', start, end)
#       8 yahoo.head()
#
# AttributeError: module 'pandas.io.data' has no attribute 'DAtaReader'

# %% [markdown]
# conda install pandas-datareader

# %%
import pandas_datareader.data as web
import datetime

start = datetime.datetime(2012, 1, 1)
end = datetime.datetime(2014, 1, 27)

yahoo = web.DataReader('MSFT', 'yahoo', start, end)
yahoo.head()
# Out:
#                  Open       High        Low      Close    Volume  Adj Close
# Date
# 2012-01-03  26.549999  26.959999  26.389999  26.770000  64731500  23.773104
# 2012-01-04  26.820000  27.469999  26.780001  27.400000  80516100  24.332575
# 2012-01-05  27.379999  27.730000  27.290001  27.680000  56081400  24.581230
# 2012-01-06  27.530001  28.190001  27.530001  28.110001  99455500  24.963092
# 2012-01-09  28.049999  28.100000  27.719999  27.740000  59706800  24.634512

# %%
goog = web.DataReader("MSFT", "google", start, end)
goog.head()
# Out:
#              Open   High    Low  Close    Volume
# Date
# 2012-01-03  26.55  26.96  26.39  26.76  64735391
# 2012-01-04  26.82  27.47  26.78  27.40  80519402
# 2012-01-05  27.38  27.73  27.29  27.68  56082205
# 2012-01-06  27.53  28.19  27.52  28.10  99459469
# 2012-01-09  28.05  28.10  27.72  27.74  59708266

# %%
aapl = pd.io.data.Options('AAPL', 'yahoo')
data = aapl.get_all_data()
data.iloc[0:6, 0:4]
# Out:
#                                              Last    Bid    Ask   Chg
# Strike Expiry     Type Symbol
# 45.0   2016-06-17 put  AAPL160617P00045000   0.04   0.01   0.06  0.00
# 47.5   2017-01-20 call AAPL170120C00047500  49.75  52.85  53.35  0.00
#                   put  AAPL170120P00047500   0.47   0.45   0.48 -0.08
#        2017-06-16 put  AAPL170616P00047500   0.84   0.73   0.92 -0.10
#        2018-01-19 call AAPL180119C00047500  48.00  51.65  53.85  0.00
#                   put  AAPL180119P00047500   1.50   1.34   1.60  0.00

# %% [markdown]
# The above took a looooong time

# %%
data.loc[(80, slice(None), 'put'), :].iloc[0:5, 0:4]
# Out:
#                                             Last   Bid   Ask   Chg
# Strike Expiry     Type Symbol
# 80     2016-03-04 put  AAPL160304P00080000  0.01  0.00  0.01  0.00
#        2016-03-11 put  AAPL160311P00080000  0.02  0.01  0.02 -0.01
#        2016-03-18 put  AAPL160318P00080000  0.02  0.02  0.03 -0.04
#        2016-03-24 put  AAPL160324P00080000  0.04  0.03  0.07 -0.06
#        2016-04-01 put  AAPL160401P00080000  0.11  0.06  0.09 -0.04

# %%
data.loc[(80, slice('20150117','20150417'), 
             'put'), :].iloc[:, 0:4]
# Out:
# Empty DataFrame
# Columns: [Last, Bid, Ask, Chg]
# Index: []

# %% [markdown]
# did the above work?

# %%
expiry = datetime.date(2015, 1, 5)
msft_calls = pd.io.data.Options('MSFT', 'yahoo').get_call_data(expiry=expiry)
msft_calls.iloc[0:5, 0:5]
# Out:
#                                             Last    Bid    Ask  Chg PctChg
# Strike Expiry     Type Symbol
# 40.0   2016-03-04 call MSFT160304C00040000  9.65  10.45  14.00    0  0.00%
# 45.0   2016-03-04 call MSFT160304C00045000  6.20   5.80   7.65    0  0.00%
# 46.0   2016-03-04 call MSFT160304C00046000  4.00   4.85   6.65    0  0.00%
# 46.5   2016-03-04 call MSFT160304C00046500  2.82   4.25   6.15    0  0.00%
# 47.0   2016-03-04 call MSFT160304C00047000  3.36   3.85   5.65    0  0.00%

# %%
expiry = datetime.date(2015, 1, 17)
aapl_calls = aapl.get_call_data(expiry=expiry)
aapl_calls.iloc[0:5, 0:4]
# Out:
#                                              Last   Bid    Ask   Chg
# Strike Expiry     Type Symbol
# 70     2016-03-04 call AAPL160304C00070000  26.52  30.4  30.70  0.00
# 75     2016-03-04 call AAPL160304C00075000  22.30  25.4  25.70  0.00
# 80     2016-03-04 call AAPL160304C00080000  16.30  20.4  20.65  0.00
# 84     2016-03-04 call AAPL160304C00084000  16.75  16.4  16.60  4.61
# 85     2016-03-04 call AAPL160304C00085000  15.40  15.4  15.60  3.35

# %% [markdown]
# ### FRED ###

# %%
gdp = web.DataReader('GDP', 'fred',
                    datetime.date(2012, 1, 1),
                    datetime.date(2014, 1, 27))
gdp
# Out:
#                 GDP
# DATE
# 2012-01-01  15973.9
# 2012-04-01  16121.9
# 2012-07-01  16227.9
# 2012-10-01  16297.3
# 2013-01-01  16440.7
# 2013-04-01  16526.8
# 2013-07-01  16727.5
# 2013-10-01  16957.6
# 2014-01-01  16984.3

# %%
wages = web.DataReader("A576RC1A027NBEA",
              "fred",
              datetime.date(1929, 1, 1),
              datetime.date(2013, 1, 1))
wages
# Out:
#             A576RC1A027NBEA
# DATE
# 1929-01-01             50.5
# 1930-01-01             46.2
# 1931-01-01             39.2
# 1932-01-01             30.5
# 1933-01-01             29.0
# ...                     ...
# 2009-01-01           6251.4
# 2010-01-01           6377.5
# 2011-01-01           6633.2
# 2012-01-01           6930.3
# 2013-01-01           7114.4
#
# [85 rows x 1 columns]

# %%
factors = web.DataReader("Global_Factors", "famafrench")
factors
# Out:
# {0:          Mkt-RF   SMB   HML    WML    RF
#  Date
#  1990-07    0.79  0.07  0.24 -99.99  0.68
#  1990-08  -10.76 -1.56  0.42 -99.99  0.66
#  1990-09  -12.24  1.68  0.34 -99.99  0.60
#  1990-10    9.58 -8.11 -3.29 -99.99  0.68
#  1990-11   -3.87  1.62  0.68  -0.32  0.57
#  ...         ...   ...   ...    ...   ...
#  2015-09   -3.91 -0.28 -0.89   3.47  0.00
#  2015-10    7.30 -2.26  0.21  -2.62  0.00
#  2015-11   -0.30  1.69 -1.78   2.11  0.00
#  2015-12   -1.74  0.93 -1.79   3.28  0.01
#  2016-01   -6.29 -2.10  0.97   0.51  0.01
#
#  [307 rows x 5 columns], 1:       Mkt-RF    SMB    HML    WML    RF
#  Date
#  1991   11.86   5.17  -7.48  11.61  5.60
#  1992   -9.65   2.15   4.23   9.72  3.51
#  1993   19.17  10.19  16.78   6.01  2.90
#  1994    2.53  -0.24   6.89   2.27  3.90
#  1995   12.97  -1.92  -4.44  10.31  5.60
#  ...      ...    ...    ...    ...   ...
#  2011   -6.79  -5.41  -4.76   6.30  0.04
#  2012   16.87  -2.55   6.41   6.35  0.06
#  2013   28.61  -0.46   5.07  23.68  0.02
#  2014    3.30  -5.03  -3.88   0.79  0.02
#  2015   -0.50   3.86 -11.12  17.10  0.02
#
#  [25 rows x 5 columns], 'DESCR': 'Global Factors\n--------------\n\nThis file was created using the 201601 Bloomberg database. Missing data are indicated by -99.99. \n\n  0 : (307 rows x 5 cols)\n  1 : Annual Factors: January-December (25 rows x 5 cols)'}

# %%
import pandas_datareader.wb as wb

all_indicators = wb.get_indicators()
# Out:
# /Users/hs3m/anaconda3/lib/python3.5/site-packages/pandas_datareader/wb.py:258: FutureWarning: sort(columns=....) is deprecated, use sort_values(by=.....)
#   data = data.sort(columns='id')

# %%
all_indicators.ix[:, 0:1]
# Out:
#                                   id
# 0                 1.0.HCount.1.25usd
# 1                   1.0.HCount.10usd
# 2                  1.0.HCount.2.5usd
# 3               1.0.HCount.Mid10to50
# 4                    1.0.HCount.Ofcl
# ...                              ...
# 15711      per_sionl.overlap_pop_urb
# 15712  per_sionl.overlap_q1_preT_tot
# 15713       per_sionl.overlap_q1_rur
# 15714       per_sionl.overlap_q1_tot
# 15715       per_sionl.overlap_q1_urb
#
# [15716 rows x 1 columns]

# %%
le_indicators = wb.search("life expectancy")
le_indicators.iloc[:3, :2]
# Out:
# /Users/hs3m/anaconda3/lib/python3.5/site-packages/pandas_datareader/wb.py:258: FutureWarning: sort(columns=....) is deprecated, use sort_values(by=.....)
#   data = data.sort(columns='id')
#                   id                                               name
# 8252     SE.SCH.LIFE  School life expectancy, primary to tertiary, b...
# 8253  SE.SCH.LIFE.FE  School life expectancy, primary to tertiary, f...
# 8254  SE.SCH.LIFE.MA  School life expectancy, primary to tertiary, m...

# %%
countries = wb.get_countries()
countries.iloc[0:10].ix[:,['name', 'capitalCity', 'iso2c']]
# Out:
#                    name       capitalCity iso2c
# 0                 Aruba        Oranjestad    AW
# 1           Afghanistan             Kabul    AF
# 2                Africa                      A9
# 3                Angola            Luanda    AO
# 4               Albania            Tirane    AL
# 5               Andorra  Andorra la Vella    AD
# 6         Andean Region                      L5
# 7            Arab World                      1A
# 8  United Arab Emirates         Abu Dhabi    AE
# 9             Argentina      Buenos Aires    AR

# %%
le_data_all = wb.download(indicator="SP.DYN.LE00.IN",
                         start='1980',
                         end='2014')
le_data_all
# Out:
# /Users/hs3m/anaconda3/lib/python3.5/site-packages/pandas_datareader/wb.py:159: FutureWarning: convert_objects is deprecated.  Use the data-type specific converters pd.to_datetime, pd.to_timedelta and pd.to_numeric.
#   out = out.convert_objects(convert_numeric=True)
#                     SP.DYN.LE00.IN
# country       year
# Canada        2014             NaN
#               2013       81.401122
#               2012       81.238049
#               2011       81.068317
#               2010       80.893488
# ...                            ...
# United States 1984       74.563415
#               1983       74.463415
#               1982       74.360976
#               1981       74.007317
#               1980       73.658537
#
# [105 rows x 1 columns]

# %%
le_data_all.index.levels[0]
# Out:
# Index(['Canada', 'Mexico', 'United States'], dtype='object', name='country')

# %%
le_data_all = wb.download(indicator="SP.DYN.LE00.IN",
                         country = countries['iso2c'],
                         start='1980',
                         end='2012')
le_data_all
# Out:
# /Users/hs3m/anaconda3/lib/python3.5/site-packages/pandas_datareader/wb.py:129: UserWarning: Non-standard ISO country codes: 1A, 1W, 4E, 7E, 8S, A4, A5, A9, B8, C4, C5, C6, C7, C8, C9, EU, F1, JG, L4, L5, L6, L7, M1, M2, OE, S1, S2, S3, S4, XC, XD, XE, XJ, XK, XL, XM, XN, XO, XP, XQ, XR, XS, XT, XU, XY, Z4, Z7, ZF, ZG, ZJ, ZQ
#   warnings.warn('Non-standard ISO country codes: %s' % tmp)
# /Users/hs3m/anaconda3/lib/python3.5/site-packages/pandas_datareader/wb.py:159: FutureWarning: convert_objects is deprecated.  Use the data-type specific converters pd.to_datetime, pd.to_timedelta and pd.to_numeric.
#   out = out.convert_objects(convert_numeric=True)
#                SP.DYN.LE00.IN
# country  year
# Aruba    2012       75.205756
#          2011       75.081390
#          2010       74.953537
#          2009       74.818146
#          2008       74.675732
# ...                       ...
# Zimbabwe 1984       61.583951
#          1983       61.148171
#          1982       60.605512
#          1981       60.004829
#          1980       59.388024
#
# [8151 rows x 1 columns]

# %%
le_data = le_data_all.reset_index().pivot(index="country", 
                                          columns="year")
le_data.ix[:,0:3]
# Out:
#                    SP.DYN.LE00.IN
# year                         1980       1981       1982
# country
# Afghanistan             41.867537  42.526927  43.230732
# Albania                 70.235976  70.454463  70.685122
# Algeria                 58.164024  59.486756  60.786341
# American Samoa                NaN        NaN        NaN
# Andorra                       NaN        NaN        NaN
# ...                           ...        ...        ...
# West Bank and Gaza            NaN        NaN        NaN
# World                   62.913617  63.217319  63.518728
# Yemen, Rep.             50.559537  51.541341  52.492707
# Zambia                  51.499195  51.217146  50.786000
# Zimbabwe                59.388024  60.004829  60.605512
#
# [247 rows x 3 columns]

# %%
country_with_least_expectancy = le_data.idxmin(axis=0)
country_with_least_expectancy
# Out:
#                 year
# SP.DYN.LE00.IN  1980       Cambodia
#                 1981       Cambodia
#                 1982    Timor-Leste
#                 1983    South Sudan
#                 1984    South Sudan
#                            ...
#                 2008        Lesotho
#                 2009        Lesotho
#                 2010        Lesotho
#                 2011        Lesotho
#                 2012        Lesotho
# dtype: object

# %%
expectancy_for_least_country = le_data.min(axis=0)
expectancy
